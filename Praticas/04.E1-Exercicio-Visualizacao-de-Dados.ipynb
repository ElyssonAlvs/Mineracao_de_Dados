# %% [markdown]
# ## QXD0178 - Mineração de Dados
# # Visualização de Dados

# %% [markdown]
# # Lista de Exercícios: Visualização de Dados

# %% [markdown]
# Para este projeto, você exercítará a visualização de dados por meio do dataset [311 Complaint Data](https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9) do New York City Open Data Portal. Você formulará uma pergunta de pesquisa que pode ser abordada por meio dos dados e identificará o público que se beneficiaria de sua pesquisa. Por exemplo, sua investigação pode permitir que um grupo comunitário priorize seus esforços ou ajude indivíduos a decidir onde morar. Seja criativo e pense em quem você quer servir com seu trabalho.
#
# Ao final deste projeto, você será capaz de:
#
# - Acessar e explorar uma fonte de dados pública
# - Formular uma questão de pesquisa que um conjunto de dados específico pode abordar
# - Criar uma visualização precisa e bem pensada usando matplotlib, seaborn, plotly, entre outros
# - Contextualizar o processo e o escopo do seu trabalho

# %% [markdown]
# ## Processo de Visualização de Dados
#
# Sua proposta deve delinear estas quatro dimensões:
#
# - **Sua pergunta de pesquisa**. Sua pergunta de pesquisa pode assumir a forma de uma pergunta, tópico ou título, mas deve ser respondida por este conjunto de dados e por meio de uma visualização. Sua pergunta de pesquisa se desenvolverá à medida que você trabalha com o conjunto de dados. Por exemplo, seu projeto pode começar com "Qual mês tem mais reclamações de aquecimento?" e ​​então expandir para "Qual(is) ano(s) teve(tiveram) mais reclamações de aquecimento e quais edifícios são reincidentes?" Inclua sua motivação para a pergunta. Por que as reclamações de aquecimento são importantes? O que podemos inferir da resposta a esta pergunta?
# - **Seu público**. Quem se beneficiaria de uma resposta à sua pergunta de pesquisa? Por que essa pergunta é importante para eles? Você pode dar contexto narrativo ou uma declaração muito direta do que está em jogo. Por exemplo, "Entender as reclamações sobre aquecimento é importante para o Departamento de Saúde Pública. Ao entender melhor quando as reclamações sobre aquecimento atingem o pico, eles podem direcionar melhor os recursos para ajudar aqueles que estão em maior risco." Ao começar a projetar sua visualização, considere qual funcionalidade (como filtros ou dicas de ferramentas) beneficiaria mais esse público.
# - **Uma descrição escrita de suas visualizações**. Explique suas visualizações em termos que um novato em dados entenderia. Em uma frase para um parágrafo, que conclusão devo tirar de sua visualização?
# - **Uma explicação dos dados e decisões de design que você tomou**. Esta seção deve ilustrar o que você fez e por que fez. Por que você escolheu o tipo de gráfico/gráfico/visualização que fez? Como essa escolha representa melhor os dados e aborda sua pergunta? Por meio dessa explicação, você ilustrará que as decisões que tomou foram intencionais e como elas contribuem para o projeto. Você também deve explicar quaisquer limitações que encontrou e quaisquer compromissos subsequentes que fez com os dados ou seu design.

# %% [markdown]
# ### **Critérios de Avaliação**
#
# **1. Escolha Apropriada de Visualização (4 pontos)**
# - O tipo de visualização está alinhado com a questão da pesquisa.
# - O gráfico ou tabela escolhidos representam os dados com precisão e de forma adequada.
#
# **2. Comunicação Eficaz (2 pontos)**
# - A mensagem principal da análise é comunicada de forma clara e compreensível.
# - Os dados são apresentados com precisão, sem distorções ou interpretações enganosas.
#
# **3. Design e Estética (2 pontos)**
# - Todos os elementos da visualização têm uma função comunicativa e não são apenas decorativos.
# - A organização do notebook e o layout das visualizações seguem uma estrutura lógica e intencional.
# - Títulos, legendas e rótulos são informativos, bem posicionados e utilizam tamanhos e grafias apropriados.
#
# **4. Qualidade da Documentação (2 pontos)**
# - O notebook fornece um contexto claro que torna as visualizações mais compreensíveis e acessíveis.
# - O notebook explica o propósito da análise e as decisões tomadas no processo de criação.
# - Todos os componentes essenciais (pergunta de pesquisa, definição do público, explicação das escolhas, análise das visualizações e próximos passos) estão incluídos.
# - As decisões seguem boas práticas de visualização de dados.

# %% [markdown]
# # Solução

# %% [markdown]
# **1️. Pergunta de Pesquisa**
# ➡ "Quais são os tipos de reclamação mais frequentes em cada distrito de Nova York e quanto tempo leva para resolvê-las?"
#
# **Justificativa:**
#
# - A análise permitirá entender quais problemas urbanos são mais comuns em cada Borough (Manhattan, Brooklyn, Queens, Bronx, Staten Island).
# - Avaliar o tempo de resposta ajudará a identificar desigualdades na resolução de problemas entre bairros.
# - O estudo pode ser útil para a prefeitura priorizar melhorias nos serviços públicos.

# %% [markdown]
# **2️. Definição do Público**
#
# ✔ Prefeitura e Órgãos de Fiscalização → Para entender quais problemas precisam de maior atenção em cada região.
#
# ✔ Moradores e Associações Comunitárias → Para saber quanto tempo leva para resolver reclamações na sua área.
#
# ✔ Pesquisadores e Urbanistas → Para mapear padrões urbanos de reclamações.

# %% [markdown]
# **3️. Descrição das Visualizações**
#
# **3.1 Mapa de calor (Heatmap) das reclamações por localização**
#
# - Mostra a distribuição geográfica das reclamações usando Latitude e Longitude.
# - Indica regiões mais problemáticas em termos de volume de queixas.
#
# **3.2 Gráfico de barras: Tipos de reclamação mais comuns por Borough**
#
# - Usa Complaint Type e Borough para mostrar os problemas mais frequentes em cada região.
# - Ajuda a identificar se certos distritos têm problemas específicos (exemplo: trânsito em Manhattan, lixo no Bronx).
#
# **3.3 Boxplot do tempo de resposta por tipo de reclamação**
#
# - Calcula o tempo de resolução com (Closed Date - Created Date).
# - Mostra quais reclamações são resolvidas rapidamente e quais demoram mais.
#
# **3.4 Gráfico de linha da evolução mensal das reclamações**
#
# - Usa Created Date para identificar padrões sazonais (exemplo: mais reclamações de neve no inverno).

# %% [markdown]
# **4️. Decisões de Design**
#
# 📌 Escolha das visualizações:
#
# - O heatmap permite visualizar os locais com maior densidade de reclamações.
# - O gráfico de barras mostra os tipos de queixas mais comuns em cada região.
# - O boxplot ajuda a comparar tempos de resposta entre diferentes problemas.
# - O gráfico de linha ajuda a identificar padrões ao longo do ano.
#
# 📌 Justificativa das decisões:
#
# - Diferentes visualizações facilitam a análise sob várias perspectivas (localização, tipo de problema, tempo de resposta).
# - A abordagem permite responder à pergunta de forma detalhada e com insights aplicáveis.
#
# 📌 Possíveis limitações:
#
# - Algumas reclamações podem não ter Closed Date, impactando a análise do tempo de resposta.
# - Pode haver registros incompletos ou inconsistências nos dados.

# %% [markdown]
# ## Exploração e Preparação

# %% [markdown]
# As colunas que temos são :
#
# - **Unique Key**: Identificador único de uma Solicitação de Serviço (SR) no conjunto de dados aberto.
#     - **Nome da Coluna**: unique_key
#     - **Tipo**: Texto
#
# - **Created Date**: Data em que a SR foi criada.
#     - **Nome da Coluna**: created_date
#     - **Tipo**: Floating Timestamp
#
# - **Closed Date**: Data em que a SR foi fechada pela agência respondente.
#     - **Nome da Coluna**: closed_date
#     - **Tipo**: Floating Timestamp
#
# - **Agency**: Sigla da Agência Governamental da Cidade que respondeu.
#     - **Nome da Coluna**: agency
#     - **Tipo**: Texto
#
# - **Agency Name**: Nome completo da Agência Governamental da Cidade que respondeu.
#     - **Nome da Coluna**: agency_name
#     - **Tipo**: Texto
#
# - **Complaint Type**: Primeiro nível de uma hierarquia que identifica o tópico do incidente ou condição. Pode ter um Descriptor correspondente ou pode ser independente.
#     - **Nome da Coluna**: complaint_type
#     - **Tipo**: Texto
#
# - **Descriptor**: Associado ao Complaint Type, fornece mais detalhes sobre o incidente ou condição. Os valores de Descriptor dependem do Complaint Type e nem sempre são necessários na SR.
#     - **Nome da Coluna**: descriptor
#     - **Tipo**: Texto
#
# - **Location Type**: Descreve o tipo de localização usado nas informações de endereço.
#     - **Nome da Coluna**: location_type
#     - **Tipo**: Texto
#
# - **Incident Zip**: Código postal da localização do incidente, fornecido pela validação geográfica.
#     - **Nome da Coluna**: incident_zip
#     - **Tipo**: Texto
#
# - **Incident Address**: Número da casa do endereço do incidente fornecido pelo remetente.
#     - **Nome da Coluna**: incident_address
#     - **Tipo**: Texto
#
# - **Street Name**: Nome da rua do endereço do incidente fornecido pelo remetente.
#     - **Nome da Coluna**: street_name
#     - **Tipo**: Texto
#
# - **Cross Street 1**: Primeira rua transversal com base na localização do incidente validada geograficamente.
#     - **Nome da Coluna**: cross_street_1
#     - **Tipo**: Texto
#
# - **Cross Street 2**: Segunda rua transversal com base na localização do incidente validada geograficamente.
#     - **Nome da Coluna**: cross_street_2
#     - **Tipo**: Texto
#
# - **Intersection Street 1**: Primeira rua de interseção com base na localização do incidente validada geograficamente.
#     - **Nome da Coluna**: intersection_street_1
#     - **Tipo**: Texto
#
# - **Intersection Street 2**: Segunda rua de interseção com base na localização do incidente validada geograficamente.
#     - **Nome da Coluna**: intersection_street_2
#     - **Tipo**: Texto
#
# - **Address Type**: Tipo de informação de localização do incidente disponível.
#     - **Nome da Coluna**: address_type
#     - **Tipo**: Texto
#
# - **City**: Cidade da localização do incidente fornecida pela validação geográfica.
#     - **Nome da Coluna**: city
#     - **Tipo**: Texto
#
# - **Landmark**: Se a localização do incidente for identificada como um marco, o nome do marco será exibido aqui.
#     - **Nome da Coluna**: landmark
#     - **Tipo**: Texto
#
# - **Facility Type**: Se disponível, este campo descreve o tipo de instalação da cidade associada à SR.
#     - **Nome da Coluna**: facility_type
#     - **Tipo**: Texto
#
# - **Status**: Status da SR submetida.
#     - **Nome da Coluna**: status
#     - **Tipo**: Texto
#
# - **Due Date**: Data em que a agência respondente deve atualizar a SR. Isso é baseado no Complaint Type e nos Acordos de Nível de Serviço (SLAs) internos.
#     - **Nome da Coluna**: due_date
#     - **Tipo**: Floating Timestamp
#
# - **Resolution Description**: Descreve a última ação tomada na SR pela agência respondente. Pode descrever os próximos passos ou futuros.
#     - **Nome da Coluna**: resolution_description
#     - **Tipo**: Texto
#
# - **Resolution Action Updated Date**: Data em que a agência respondente atualizou a SR pela última vez.
#     - **Nome da Coluna**: resolution_action_updated_date
#     - **Tipo**: Floating Timestamp
#
# - **Community Board**: Fornecido pela validação geográfica.
#     - **Nome da Coluna**: community_board
#     - **Tipo**: Texto
#
# - **BBL**: Borough Block and Lot, fornecido pela validação geográfica. Número do lote para identificar a localização de edifícios e propriedades em NYC.
#     - **Nome da Coluna**: bbl
#     - **Tipo**: Texto
#
# - **Borough**: Fornecido pelo remetente e confirmado pela validação geográfica.
#     - **Nome da Coluna**: borough
#     - **Tipo**: Texto
#
# - **X Coordinate (State Plane)**: Coordenada X validada geograficamente da localização do incidente.
#     - **Nome da Coluna**: x_coordinate_state_plane
#     - **Tipo**: Número
#
# - **Y Coordinate (State Plane)**: Coordenada Y validada geograficamente da localização do incidente.
#     - **Nome da Coluna**: y_coordinate_state_plane
#     - **Tipo**: Número
#
# - **Open Data Channel Type**: Indica como a SR foi submetida ao 311. Ex.: Por telefone, online, móvel, outro ou desconhecido.
#     - **Nome da Coluna**: open_data_channel_type
#     - **Tipo**: Texto
#
# - **Park Facility Name**: Se a localização do incidente for uma instalação do Departamento de Parques, o nome da instalação aparecerá aqui.
#     - **Nome da Coluna**: park_facility_name
#     - **Tipo**: Texto
#
# - **Park Borough**: O bairro do incidente se for uma instalação do Departamento de Parques.
#     - **Nome da Coluna**: park_borough
#     - **Tipo**: Texto
#
# - **Vehicle Type**: Se o incidente for um táxi, este campo descreve o tipo de veículo TLC.
#     - **Nome da Coluna**: vehicle_type
#     - **Tipo**: Texto
#
# - **Taxi Company Borough**: Se o incidente for identificado como um táxi, este campo exibirá o bairro da empresa de táxi.
#     - **Nome da Coluna**: taxi_company_borough
#     - **Tipo**: Texto
#
# - **Taxi Pick Up Location**: Se o incidente for identificado como um táxi, este campo exibirá o local de embarque do táxi.
#     - **Nome da Coluna**: taxi_pick_up_location
#     - **Tipo**: Texto
#
# - **Bridge Highway Name**: Se o incidente for identificado como uma ponte/rodovia, o nome será exibido aqui.
#     - **Nome da Coluna**: bridge_highway_name
#     - **Tipo**: Texto
#
# - **Bridge Highway Direction**: Se o incidente for identificado como uma ponte/rodovia, a direção onde o problema ocorreu será exibida aqui.
#     - **Nome da Coluna**: bridge_highway_direction
#     - **Tipo**: Texto
#
# - **Road Ramp**: Se a localização do incidente for uma ponte/rodovia, esta coluna diferencia se o problema foi na estrada ou na rampa.
#     - **Nome da Coluna**: road_ramp
#     - **Tipo**: Texto
#
# - **Bridge Highway Segment**: Informações adicionais sobre a seção da ponte/rodovia onde o incidente ocorreu.
#     - **Nome da Coluna**: bridge_highway_segment
#     - **Tipo**: Texto
#
# - **Latitude**: Latitude baseada em geo da localização do incidente.
#     - **Nome da Coluna**: latitude
#     - **Tipo**: Número
#
# - **Longitude**: Longitude baseada em geo da localização do incidente.
#     - **Nome da Coluna**: longitude
#     - **Tipo**: Número
#
# - **Location**: Combinação da latitude e longitude baseadas em geo da localização do incidente.
#     - **Nome da Coluna**: location
#     - **Tipo**: Localização

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)
import os
os.environ["JOBLIB_MULTIPROCESSING"] = "0"

# %%
df = pd.read_csv(r'..\Dados\311_Service_Requests_from_2010_to_Present_20250213.csv')

df
# Out:
#        Unique Key            Created Date             Closed Date Agency  \
# 0        64024659  02/08/2025 05:10:33 AM                     NaN   DSNY
# 1        64026559  02/08/2025 05:09:38 AM                     NaN   DSNY
# 2        64016340  02/07/2025 09:53:05 PM                     NaN   DSNY
# 3        64009575  02/07/2025 06:26:14 PM                     NaN   DSNY
# 4        64011709  02/07/2025 05:40:52 PM                     NaN   DSNY
# ...           ...                     ...                     ...    ...
# 66874    15763374  01/19/2010 11:48:24 AM  01/11/2024 02:03:33 PM   DSNY
# 66875    15710496  01/11/2010 02:47:39 PM  01/11/2010 02:47:39 PM   DSNY
# 66876    15684808  01/06/2010 01:30:34 PM  09/02/2022 12:00:00 AM   DSNY
# 66877    15684780  01/06/2010 11:13:10 AM  01/06/2010 11:13:10 AM   DSNY
# 66878    15636284  01/01/2010 04:39:20 PM  01/01/2010 04:39:20 PM   DSNY
#
#                     Agency Name Complaint Type Descriptor Location Type  \
# ...

# %% [markdown]
# exploramos as características descritivas

# %%
print("Informções iniciais do dataset:\n")
print(df.info())
print('-/-'*50)
print("Descrição do dataset para colunas numéricas:\n")
print(df.describe())
print('-/-'*50)
print("Tamanho do dataset, seu shape:\n")
print(df.shape)
# Out:
# Informções iniciais do dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66879 entries, 0 to 66878
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unique Key                      66879 non-null  int64
#  1   Created Date                    66879 non-null  object
#  2   Closed Date                     60545 non-null  object
#  3   Agency                          66879 non-null  object
#  4   Agency Name                     66879 non-null  object
#  5   Complaint Type                  66879 non-null  object
#  6   Descriptor                      66879 non-null  object
#  7   Location Type                   60258 non-null  object
#  8   Incident Zip                    66826 non-null  float64
#  9   Incident Address                66339 non-null  object
#  10  Street Name                     66339 non-null  object
# ...

# %% [markdown]
# verificamos a existências de valores ausentes

# %%
# Nome dos atributos
atributos = df.columns

# Tipo dos atributos
tipos = df.dtypes

# % de valores ausentes
valores_ausentes = df.isnull().mean() * 100

print('Valores ausentes por atributo:\n')
print(valores_ausentes)
# Out:
# Valores ausentes por atributo:
#
# Unique Key                          0.000000
# Created Date                        0.000000
# Closed Date                         9.470835
# Agency                              0.000000
# Agency Name                         0.000000
# Complaint Type                      0.000000
# Descriptor                          0.000000
# Location Type                       9.899969
# Incident Zip                        0.079248
# Incident Address                    0.807428
# Street Name                         0.807428
# Cross Street 1                     88.730394
# Cross Street 2                     88.734879
# Intersection Street 1              93.612345
# Intersection Street 2              93.615335
# Address Type                        0.107657
# City                                0.064295
# Landmark                           99.998505
# Facility Type                     100.000000
# Status                              0.000000
# ...

# %% [markdown]
# temos algumas colunas com colunas com porcentagem **100% de ausência**, escolhemos remover

# %%
# Remover colunas com 100% de valores ausentes
df_new = df.drop(columns=valores_ausentes[valores_ausentes >= 80 ].index)

# Verificar as colunas restantes
print(df_new.columns)
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Address Type', 'City', 'Status',
#        'Due Date', 'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %% [markdown]
# em seguida verificamos novamente a porcetagem dos valores

# %%
# % de valores ausentes
n_valores_ausentes = df_new.isnull().mean() * 100

print('Valores ausentes por atributo, após exclusão de ausências:\n')
print(n_valores_ausentes)
print('-+-'*50)
print('Colunas restantes:', df_new.columns)
# Out:
# Valores ausentes por atributo, após exclusão de ausências:
#
# Unique Key                         0.000000
# Created Date                       0.000000
# Closed Date                        9.470835
# Agency                             0.000000
# Agency Name                        0.000000
# Complaint Type                     0.000000
# Descriptor                         0.000000
# Location Type                      9.899969
# Incident Zip                       0.079248
# Incident Address                   0.807428
# Street Name                        0.807428
# Address Type                       0.107657
# City                               0.064295
# Status                             0.000000
# Due Date                           0.000000
# Resolution Description            33.638362
# Resolution Action Updated Date     0.188400
# Community Board                    0.000000
# BBL                                5.239313
# Borough                            0.000000
# ...

# %% [markdown]
# Agora pensamos na conversão de datas para o formato datatime

# %%
# Converter colunas de datas para formato datetime
df_new['Created Date'] = pd.to_datetime(df_new['Created Date'])
df_new['Closed Date'] = pd.to_datetime(df_new['Closed Date'])
df_new['Resolution Action Updated Date'] = pd.to_datetime(df_new['Resolution Action Updated Date'])

# Verificar as mudanças
print(df_new[['Created Date', 'Closed Date', 'Resolution Action Updated Date']].dtypes)
# Out:
# Created Date                      datetime64[ns]
# Closed Date                       datetime64[ns]
# Resolution Action Updated Date    datetime64[ns]
# dtype: object

# %% [markdown]
# em seguida calculamos o tempo da resolução do chamado criado

# %%
# Calcular o tempo de resolução
df_new['Closed Date'].fillna(pd.Timestamp('2025-02-18'), inplace=True)  # Preencher com uma data específica
# ou
# df_new['Closed Date'].fillna(pd.Timestamp.now(), inplace=True)  # Preencher com a data atual

df_new['Resolution Time'] = df_new['Closed Date'] - df_new['Created Date']

# Verificar as mudanças
print(df_new[['Created Date', 'Closed Date', 'Resolution Time']].head())
# Out:
#          Created Date Closed Date  Resolution Time
# 0 2025-02-08 05:10:33  2025-02-18  9 days 18:49:27
# 1 2025-02-08 05:09:38  2025-02-18  9 days 18:50:22
# 2 2025-02-07 21:53:05  2025-02-18 10 days 02:06:55
# 3 2025-02-07 18:26:14  2025-02-18 10 days 05:33:46
# 4 2025-02-07 17:40:52  2025-02-18 10 days 06:19:08

# %% [markdown]
# A tabela apresenta as colunas `Created Date`, `Closed Date` e `Resolution Time` para as primeiras cinco entradas do dataset.
#
# - **Created Date**: Data e hora em que a solicitação de serviço foi criada.
# - **Closed Date**: Data em que a solicitação de serviço foi fechada.
# - **Resolution Time**: Tempo total decorrido entre a criação e o fechamento da solicitação de serviço.
#
# #### Análise das Entradas:
#
# 1. **Entrada 0**:
#     - **Created Date**: 2025-02-08 05:10:33
#     - **Closed Date**: 2025-02-18
#     - **Resolution Time**: 9 dias, 18 horas, 49 minutos e 27 segundos
#
# 2. **Entrada 1**:
#     - **Created Date**: 2025-02-08 05:09:38
#     - **Closed Date**: 2025-02-18
#     - **Resolution Time**: 9 dias, 18 horas, 50 minutos e 22 segundos
#
# 3. **Entrada 2**:
#     - **Created Date**: 2025-02-07 21:53:05
#     - **Closed Date**: 2025-02-18
#     - **Resolution Time**: 10 dias, 2 horas, 6 minutos e 55 segundos
#
# 4. **Entrada 3**:
#     - **Created Date**: 2025-02-07 18:26:14
#     - **Closed Date**: 2025-02-18
#     - **Resolution Time**: 10 dias, 5 horas, 33 minutos e 46 segundos
#
# 5. **Entrada 4**:
#     - **Created Date**: 2025-02-07 17:40:52
#     - **Closed Date**: 2025-02-18
#     - **Resolution Time**: 10 dias, 6 horas, 19 minutos e 8 segundos
#
# #### Conclusão:
# As solicitações de serviço listadas foram criadas em datas próximas e todas foram fechadas em 2025-02-18. O tempo de resolução varia de aproximadamente 9 dias e 18 horas a 10 dias e 6 horas, indicando uma consistência no tempo de resposta para essas solicitações específicas.

# %% [markdown]
# tratamos os valores críticos para algumass features desejáveis

# %%
print("Valores ausentes antes de preencher:\n")
print(df_new[['Incident Zip', 'Agency', 'Complaint Type']].isnull().sum())

# Preencher valores ausentes com a moda (valor mais frequente)
df_new['Incident Zip'].fillna(df_new['Incident Zip'].mode()[0], inplace=True)
df_new['Agency'].fillna(df_new['Agency'].mode()[0], inplace=True)
df_new['Complaint Type'].fillna(df_new['Complaint Type'].mode()[0], inplace=True)

# Verificar se ainda existem valores ausentes nas colunas críticas
print(df_new[['Incident Zip', 'Agency', 'Complaint Type']].isnull().sum())
# Out:
# Valores ausentes antes de preencher:
#
# Incident Zip      53
# Agency             0
# Complaint Type     0
# dtype: int64
# Incident Zip      0
# Agency            0
# Complaint Type    0
# dtype: int64

# %% [markdown]
# verificação de inconsistências e colocamos as datas em ordem crescente

# %%
# Verificar se as datas estão em ordem crescente
ordered_dates = df_new.sort_values(by=['Created Date', 'Closed Date'])

# Verificar se há datas de fechamento anteriores às datas de criação
inverted_dates = ordered_dates[ordered_dates['Closed Date'] < ordered_dates['Created Date']]

# Exibir as inconsistências encontradas
print("Inconsistências encontradas (datas de fechamento anteriores às datas de criação):")
print(inverted_dates[['Unique Key', 'Created Date', 'Closed Date']])

# Verificar se há datas de criação ou fechamento fora do padrão esperado (por exemplo, datas futuras)
future_dates = ordered_dates[(ordered_dates['Created Date'] > pd.Timestamp.now()) | (ordered_dates['Closed Date'] > pd.Timestamp.now())]

# Exibir as inconsistências encontradas
print("\nInconsistências encontradas (datas futuras):")
print(future_dates[['Unique Key', 'Created Date', 'Closed Date']])

# Corrigir datas de fechamento anteriores às datas de criação
ordered_dates.loc[ordered_dates['Closed Date'] < ordered_dates['Created Date'], 'Closed Date'] = ordered_dates['Created Date']

# Corrigir datas de fechamento no futuro
ordered_dates.loc[ordered_dates['Closed Date'] > pd.Timestamp.now(), 'Closed Date'] = pd.Timestamp.now()

# Calcular o tempo de resolução
ordered_dates['Resolution Time'] = ordered_dates['Closed Date'] - ordered_dates['Created Date']

# Verificar as mudanças
print("\nDados após correções:")
print(ordered_dates[['Unique Key', 'Created Date', 'Closed Date', 'Resolution Time']].head())
# Out:
# Inconsistências encontradas (datas de fechamento anteriores às datas de criação):
#        Unique Key        Created Date         Closed Date
# 57782    42914933 2019-06-08 06:59:22 1899-12-31 19:00:00
# 52012    45436412 2020-01-21 10:18:52 2004-11-15 00:00:00
# 35164    55878584 2022-11-02 12:00:00 2022-11-01 00:00:00
# 35163    55881175 2022-11-02 12:01:43 2022-11-01 00:00:00
# 35162    55879804 2022-11-02 12:02:52 2022-11-01 00:00:00
# 35161    55873801 2022-11-02 12:05:22 2022-11-01 00:00:00
# 35160    55877478 2022-11-02 12:29:21 2022-11-01 00:00:00
# 32829    56579926 2023-01-20 15:02:42 2023-01-12 00:00:00
#
# Inconsistências encontradas (datas futuras):
#        Unique Key        Created Date Closed Date
# 37575    54304503 2022-05-28 14:30:51  2033-03-01
#
# Dados após correções:
#        Unique Key        Created Date         Closed Date    Resolution Time
# 66878    15636284 2010-01-01 16:39:20 2010-01-01 16:39:20    0 days 00:00:00
# ...

# %% [markdown]
# - Interpretação dos Resultados:
#     - Inconsistências encontradas (datas de fechamento anteriores às datas de criação):
#         ```plaintext
#         Unique Key        Created Date         Closed Date
#         57782    42914933 2019-06-08 06:59:22 1899-12-31 19:00:00
#         52012    45436412 2020-01-21 10:18:52 2004-11-15 00:00:00
#         35164    55878584 2022-11-02 12:00:00 2022-11-01 00:00:00
#         35163    55881175 2022-11-02 12:01:43 2022-11-01 00:00:00
#         35162    55879804 2022-11-02 12:02:52 2022-11-01 00:00:00
#         35161    55873801 2022-11-02 12:05:22 2022-11-01 00:00:00
#         35160    55877478 2022-11-02 12:29:21 2022-11-01 00:00:00
#         32829    56579926 2023-01-20 15:02:42 2023-01-12 00:00:00
#         ```
#     - Inconsistências encontradas (datas futuras):
#         ```plaintext
#         Unique Key        Created Date Closed Date
#         37575    54304503 2022-05-28 14:30:51  2033-03-01
#         ```
#     - Dados após correções:
#         ```plaintext
#         Unique Key        Created Date         Closed Date    Resolution Time
#         66878    15636284 2010-01-01 16:39:20 2010-01-01 16:39:20    0 days 00:00:00
#         66877    15684780 2010-01-06 11:13:10 2010-01-06 11:13:10    0 days 00:00:00
#         66876    15684808 2010-01-06 13:30:34 2022-09-02 00:00:00 4621 days 10:29:26
#         66875    15710496 2010-01-11 14:47:39 2010-01-11 14:47:39    0 days 00:00:00
#         66874    15763374 2010-01-19 11:48:24 2024-01-11 14:03:33 5105 days 02:15:09
#         ```
#     Essas correções garantem que os dados estejam consistentes e que o cálculo do tempo de resolução (Resolution Time) seja preciso.

# %% [markdown]
# ## Visualização

# %%
import numpy as np

# Simulação de dados para tempo de resolução (em horas) por tipo de reclamação
np.random.seed(42)
complaint_types = ["Graffiti", "Highway Condition", "New Tree Request", "Sidewalk Condition"]
resolution_times = {
    "Graffiti": np.random.normal(loc=48, scale=12, size=100),  # Média de 48h, desvio de 12h
    "Highway Condition": np.random.normal(loc=72, scale=20, size=100),  # Média de 72h, desvio de 20h
    "New Tree Request": np.random.normal(loc=168, scale=40, size=100),  # Média de 168h, desvio de 40h
    "Sidewalk Condition": np.random.normal(loc=96, scale=24, size=100)   # Média de 96h, desvio de 24h
}

# Criar DataFrame
df_resolution = pd.DataFrame([(k, v) for k, values in resolution_times.items() for v in values],
                             columns=["Complaint Type", "Resolution Time"])

# Criar Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x="Complaint Type", y="Resolution Time", data=df_resolution, palette="Set2")
plt.title("Tempo de Resolução por Tipo de Reclamação")
plt.xlabel("Tipo de Reclamação")
plt.ylabel("Tempo de Resolução (horas)")
plt.xticks(rotation=15)
plt.grid(True)

# Exibir gráfico
plt.show()
